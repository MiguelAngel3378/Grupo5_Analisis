# %%
import pandas as pd
import numpy as np
import seaborn as sns
import plotly.express as px

# %%
wrld_pop=pd.read_csv('../../Data/FuentesOriginales/USAR/population.csv')

# %%
len(wrld_pop[wrld_pop.duplicated()])
# Out:
# 0

# %%
wrld_pop.isna().sum()
# Out:
# Unnamed: 0            0
# Continent             0
# Country               0
# Year                  0
# Population            0
# Yearly%Change         0
# YearlyChange          0
# Migrants(net)         0
# MedianAge             0
# FertilityRate         0
# UrbanPop%             0
# UrbanPopulation       0
# Country%OfWorldPop    0
# GlobalRank            0
# dtype: int64

# %%
del wrld_pop['Unnamed: 0']

# %%
wrld_pop.isin([0]).sum()
# Out:
# Continent                0
# Country                  0
# Year                     0
# Population               0
# Yearly%Change           11
# YearlyChange             7
# Migrants(net)          764
# MedianAge              612
# FertilityRate          612
# UrbanPop%               72
# UrbanPopulation         72
# Country%OfWorldPop    1071
# GlobalRank               0
# dtype: int64

# %%
wrld_pop.dtypes
# Out:
# Continent              object
# Country                object
# Year                    int64
# Population              int64
# Yearly%Change         float64
# YearlyChange            int64
# Migrants(net)           int64
# MedianAge             float64
# FertilityRate         float64
# UrbanPop%             float64
# UrbanPopulation         int64
# Country%OfWorldPop    float64
# GlobalRank              int64
# dtype: object

# %%
wrld_pop.head()
# Out:
#   Continent      Country  Year  Population  Yearly%Change  YearlyChange
# 0      Asia  Afghanistan  1955     8270991           1.30        103775  \
# 1      Asia  Afghanistan  1960     8996973           1.70        145196
# 2      Asia  Afghanistan  1965     9956320           2.05        191869
# 3      Asia  Afghanistan  1970    11173642           2.33        243464
# 4      Asia  Afghanistan  1975    12689160           2.58        303104
#
#    Migrants(net)  MedianAge  FertilityRate  UrbanPop%  UrbanPopulation
# 0          -4000       19.2           7.45        7.1           587818  \
# 1          -4000       18.8           7.45        8.4           755797
# 2          -4000       18.4           7.45        9.9           984350
# 3          -4000       17.9           7.45       11.6          1295433
# 4          -4000       17.3           7.45       13.5          1717422
#
#    Country%OfWorldPop  GlobalRank
# 0                0.30          48
# 1                0.30          48
# ...

# %%
wrld_pop.shape
# Out:
# (4230, 13)

# %%
print('Min Year',wrld_pop.Year.min())
print('Max Year',wrld_pop.Year.max())
# Out:
# Min Year 1955
# Max Year 2020

# %%
## Adding Country Code column based on Country 
import pycountry

def do_fuzzy_search(country):
    try:
        result = pycountry.countries.search_fuzzy(country)
        return result[0].alpha_3
    except:
        return np.nan

wrld_pop["Country_code"] = wrld_pop["Country"].apply(lambda country: do_fuzzy_search(country))

# %%
px.choropleth(wrld_pop,locations='Country_code',color='FertilityRate',hover_name='Country',animation_frame='Year',
            color_continuous_scale=px.colors.sequential.Reds, projection='natural earth',
            title='Global Fertility Rate')
