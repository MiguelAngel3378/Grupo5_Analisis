# %%
import numpy as np
import pandas as pd

datos = np.random.randint(0, 100, size=50)
df = pd.DataFrame(datos, columns=["Datos"])

# %%
dfi.export(df.describe(), "tabla.png", fontsize=24, table_conversion="matplotlib")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 dfi.export(df.describe(), "tabla.png", fontsize=24, table_conversion="matplotlib")
#
# NameError: name 'dfi' is not defined

# %%
import matplotlib.pyplot as plt

plt.plot(datos)
plt.savefig("grafica.png", dpi=300)

# %%
from pptx import Presentation
from pptx.util import Inches

prs = Presentation()
title_slide_layout = prs.slide_layouts[0]
blank_slide_layout = prs.slide_layouts[6]

# Diapositiva del titulo
slide = prs.slides.add_slide(title_slide_layout)
title = slide.shapes.title
subtitle = slide.placeholders[1]
title.text = "Esto es una demo"
subtitle.text = "Gráficas y tablas"

# Diapositiva con un gráfico matplotlib
slide = prs.slides.add_slide(blank_slide_layout)
slide.shapes.add_picture("grafica.png", left=Inches(1), top=Inches(1), height=Inches(5.5))

# Diapositiva con tabla pandas y gráfica
slide = prs.slides.add_slide(blank_slide_layout)
slide.shapes.add_picture("tabla.png", left=Inches(1), top=Inches(1), height=Inches(4.5))
slide.shapes.add_picture("grafica.png", left=Inches(4), top=Inches(1), height=Inches(3.5))

prs.save('test.pptx')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[5], line 21
#      19 # Diapositiva con tabla pandas y gráfica
#      20 slide = prs.slides.add_slide(blank_slide_layout)
# ---> 21 slide.shapes.add_picture("tabla.png", left=Inches(1), top=Inches(1), height=Inches(4.5))
#      22 slide.shapes.add_picture("grafica.png", left=Inches(4), top=Inches(1), height=Inches(3.5))
#      24 prs.save('test.pptx')
#
# File c:\Users\migue\AppData\Local\Programs\Python\Python310-32\lib\site-packages\pptx\shapes\shapetree.py:332, in _BaseGroupShapes.add_picture(self, image_file, left, top, width, height)
#     321 def add_picture(self, image_file, left, top, width=None, height=None):
#     322     """Add picture shape displaying image in *image_file*.
#     323
#     324     *image_file* can be either a path to a file (a string) or a file-like
#    (...)
#     330     without regard to its native aspect ratio.
#     331     """
# --> 332     image_part, rId = self.part.get_or_add_image_part(image_file)
#     333     pic = self._add_pic_from_image_part(image_part, rId, left, top, width, height)
#     334     self._recalculate_extents()
#
# File c:\Users\migue\AppData\Local\Programs\Python\Python310-32\lib\site-packages\pptx\parts\slide.py:39, in BaseSlidePart.get_or_add_image_part(self, image_file)
#      32 def get_or_add_image_part(self, image_file):
#      33     """Return `(image_part, rId)` pair corresponding to `image_file`.
#      34
#      35     The returned |ImagePart| object contains the image in `image_file` and is
#      36     related to this slide with the key `rId`. If either the image part or
#      37     relationship already exists, they are reused, otherwise they are newly created.
#      38     """
# ---> 39     image_part = self._package.get_or_add_image_part(image_file)
#      40     rId = self.relate_to(image_part, RT.IMAGE)
#      41     return image_part, rId
#
# File c:\Users\migue\AppData\Local\Programs\Python\Python310-32\lib\site-packages\pptx\package.py:36, in Package.get_or_add_image_part(self, image_file)
#      30 def get_or_add_image_part(self, image_file):
#      31     """
#      32     Return an |ImagePart| object containing the image in *image_file*. If
#      33     the image part already exists in this package, it is reused,
#      34     otherwise a new one is created.
#      35     """
# ---> 36     return self._image_parts.get_or_add_image_part(image_file)
#
# File c:\Users\migue\AppData\Local\Programs\Python\Python310-32\lib\site-packages\pptx\package.py:151, in _ImageParts.get_or_add_image_part(self, image_file)
#     144 def get_or_add_image_part(self, image_file):
#     145     """Return |ImagePart| object containing the image in `image_file`.
#     146
#     147     `image_file` can be either a path to an image file or a file-like object
#     148     containing an image. If an image part containing this same image already exists,
#     149     that instance is returned, otherwise a new image part is created.
#     150     """
# --> 151     image = Image.from_file(image_file)
#     152     image_part = self._find_by_sha1(image.sha1)
#     153     return ImagePart.new(self._package, image) if image_part is None else image_part
#
# File c:\Users\migue\AppData\Local\Programs\Python\Python310-32\lib\site-packages\pptx\parts\image.py:162, in Image.from_file(cls, image_file)
#     156 """
#     157 Return a new |Image| object loaded from *image_file*, which can be
#     158 either a path (string) or a file-like object.
#     159 """
#     160 if is_string(image_file):
#     161     # treat image_file as a path
# --> 162     with open(image_file, "rb") as f:
#     163         blob = f.read()
#     164     filename = os.path.basename(image_file)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'tabla.png'
